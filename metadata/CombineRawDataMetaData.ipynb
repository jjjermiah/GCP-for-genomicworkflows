# %% [markdown]
# # CCLE RAW DATA EXPLORATION
# ### This notebook is for reading in a set of metadata files from various sources to create a database of metadata + file location for the raw CCLE data

# %%
import pandas as pd
import requests
import os

# %% [markdown]
# # Data from the TERRA platform
# https://app.terra.bio/#workspaces/fccredits-silver-tan-7621/CCLE_v2
#
# Each cell contains a link to the google bucket location for each
#
# Obtained : August 2023
#
# The following raw sequencing data is available for download:
#
# - RNAseq (1025) [HG38]
# - WES (478) [HG38 + HG19]
# - WGS (329) [HG38 + HG19]
# - RRBS (unfiltered) (927) [HG19]
# - HC (976) [HG19]
# - Raindance (782) [HG19]

# %%
# Read in file at ./terra_combined_paths.csv
file_path = './Terra_ExportedList.tsv'
terra_df = pd.read_csv(file_path, sep='\t')
terra_df.head()
# Out:
#   entity:sample_id                                      hg19_RRBS_bai  \
# 0       ACH-000001  gs://cclebams/RRBS/G29750/NIH_OVCAR-3/v1/NIH_O...
# 1       ACH-000002       gs://cclebams/RRBS/G29750/HL-60/v2/HL-60.bai
# 2       ACH-000003                                                NaN
# 3       ACH-000004      gs://cclebams/RRBS/G48942/HEL/current/HEL.bai
# 4       ACH-000005  gs://cclebams/RRBS/G29750/HEL_92.1.7/v2/HEL_92...
#
#                                        hg19_RRBS_bam  \
# 0  gs://cclebams/RRBS/G29750/NIH_OVCAR-3/v1/NIH_O...
# 1       gs://cclebams/RRBS/G29750/HL-60/v2/HL-60.bam
# 2                                                NaN
# 3      gs://cclebams/RRBS/G48942/HEL/current/HEL.bam
# 4  gs://cclebams/RRBS/G29750/HEL_92.1.7/v2/HEL_92...
#
#                              hg19_hybrid_capture_bai  \
# 0   gs://cclebams/hybrid_capture/NIHOVCAR3_OVARY.bai
# 1             gs://cclebams/hybrid_capture/HL-60.bai
# 2                                                NaN
# 3  gs://cclebams/hybrid_capture/HEL_HAEMATOPOIETI...
# 4  gs://cclebams/hybrid_capture/HEL9217_HAEMATOPO...
#
#                              hg19_hybrid_capture_bam  \
# 0   gs://cclebams/hybrid_capture/NIHOVCAR3_OVARY.bam
# 1             gs://cclebams/hybrid_capture/HL-60.bam
# 2                                                NaN
# 3  gs://cclebams/hybrid_capture/HEL_HAEMATOPOIETI...
# 4  gs://cclebams/hybrid_capture/HEL9217_HAEMATOPO...
#
#                                   hg19_raindance_bai  \
# 0  gs://cclebams/raindance/G16640/NIH_OVCAR-3/cur...
# 1                  gs://cclebams/raindance/HL-60.bai
# 2                                                NaN
# 3                                                NaN
# 4  gs://cclebams/raindance/G16640/HEL_92.1.7/curr...
#
#                                   hg19_raindance_bam hg19_targeted_bai  \
# 0  gs://cclebams/raindance/G16640/NIH_OVCAR-3/cur...               NaN
# 1                  gs://cclebams/raindance/HL-60.bam               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4  gs://cclebams/raindance/G16640/HEL_92.1.7/curr...               NaN
#
#   hg19_targeted_bam                                       hg38_rna_bai  ...  \
# 0               NaN  gs://cclebams/rnasq_hg38/CDS-VqxBGH.Aligned.so...  ...
# 1               NaN  gs://cclebams/rnasq_hg38/CDS-AExPJi.Aligned.so...  ...
# 2               NaN  gs://cclebams/rnasq_hg38/CDS-TyidZO.Aligned.so...  ...
# 3               NaN  gs://cclebams/rnasq_hg38/CDS-Sl0JI6.Aligned.so...  ...
# 4               NaN  gs://cclebams/rnasq_hg38/CDS-wsWPxR.Aligned.so...  ...
#
#                                      hg38_wes_bai  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3  gs://cclebams/hg38_wes/CDS-7ffA1d.hg38.bam.bai
# 4  gs://cclebams/hg38_wes/CDS-bweujf.hg38.bam.bai
#
#                                  hg38_wes_bam  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  gs://cclebams/hg38_wes/CDS-7ffA1d.hg38.bam
# 4  gs://cclebams/hg38_wes/CDS-bweujf.hg38.bam
#
#                                      hg38_wgs_bai  \
# 0  gs://cclebams/wgs_hg38/CDS-1pLoxn.wgs_ccle.bai
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4  gs://cclebams/wgs_hg38/CDS-17moNf.wgs_ccle.bai
#
#                                      hg38_wgs_bam  \
# 0  gs://cclebams/wgs_hg38/CDS-1pLoxn.wgs_ccle.bam
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4  gs://cclebams/wgs_hg38/CDS-17moNf.wgs_ccle.bam
#
#                                  mutect2_parquet_wes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  ["gs://ccle-mutation/mutect2_parquet/d7afb11fb...
# 4  ["gs://ccle-mutation/mutect2_parquet/04a2bf1d8...
#
#                                  mutect2_parquet_wgs  \
# 0  ["gs://ccle-mutation/mutect2_parquet/0f5356e34...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      mutect2_vcf_wes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  gs://ccle-mutation/mutect2_vcf/CDS-7ffA1d_fixe...
# 4  gs://ccle-mutation/mutect2_vcf/CDS-bweujf_fixe...
#
#                                      mutect2_vcf_wgs participant  \
# 0  gs://ccle-mutation/mutect2_vcf/CDS-1pLoxn_fixe...  ACH-000001
# 1                                                NaN  ACH-000002
# 2                                                NaN  ACH-000003
# 3                                                NaN  ACH-000004
# 4                                                NaN  ACH-000005
#
#   stripped_cell_line_name
# 0               NIHOVCAR3
# 1                    HL60
# 2                   CACO2
# 3                     HEL
# 4                 HEL9217
#
# [5 rows x 21 columns]

# %%
terra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   entity:sample_id         1060 non-null   object
#  1   hg19_RRBS_bai            927 non-null    object
#  2   hg19_RRBS_bam            927 non-null    object
#  3   hg19_hybrid_capture_bai  973 non-null    object
#  4   hg19_hybrid_capture_bam  973 non-null    object
#  5   hg19_raindance_bai       782 non-null    object
#  6   hg19_raindance_bam       782 non-null    object
#  7   hg19_targeted_bai        187 non-null    object
#  8   hg19_targeted_bam        187 non-null    object
#  9   hg38_rna_bai             1025 non-null   object
#  10  hg38_rna_bam             1025 non-null   object
#  11  hg38_wes_bai             474 non-null    object
#  12  hg38_wes_bam             474 non-null    object
#  13  hg38_wgs_bai             356 non-null    object
#  14  hg38_wgs_bam             356 non-null    object
#  15  mutect2_parquet_wes      474 non-null    object
#  16  mutect2_parquet_wgs      328 non-null    object
#  17  mutect2_vcf_wes          474 non-null    object
#  18  mutect2_vcf_wgs          328 non-null    object
#  19  participant              1060 non-null   object
#  20  stripped_cell_line_name  1060 non-null   object
# dtypes: object(21)
# memory usage: 174.0+ KB

# %% [markdown]
# # Data from ENA Web Browser
# https://www.ebi.ac.uk/ena/browser/view/PRJNA523380
#
# Obtained: August 2023

# %%
# read ENA_browser_PRJNA523380.tsv file and store in ena_df
ena_df = pd.read_csv('./ENA_browser_PRJNA523380.tsv', sep='\t')
ena_df.head()
# Out:
#   run_accession sample_accession secondary_sample_accession  \
# 0    SRR8615033     SAMN10988141                 SRS4395287
# 1    SRR8615034     SAMN10988287                 SRS4395286
# 2    SRR8615035     SAMN10989587                 SRS4395285
# 3    SRR8615042     SAMN10987804                 SRS4395278
# 4    SRR8615047     SAMN10987678                 SRS4395273
#
#   experiment_accession study_accession  tax_id scientific_name  \
# 0           SRX5414207     PRJNA523380    9606    Homo sapiens
# 1           SRX5414206     PRJNA523380    9606    Homo sapiens
# 2           SRX5414205     PRJNA523380    9606    Homo sapiens
# 3           SRX5414198     PRJNA523380    9606    Homo sapiens
# 4           SRX5414193     PRJNA523380    9606    Homo sapiens
#
#   instrument_platform library_layout library_source  ...  \
# 0            ILLUMINA         PAIRED        GENOMIC  ...
# 1            ILLUMINA         PAIRED        GENOMIC  ...
# 2            ILLUMINA         PAIRED        GENOMIC  ...
# 3            ILLUMINA         PAIRED        GENOMIC  ...
# 4            ILLUMINA         PAIRED        GENOMIC  ...
#
#                             study_title     run_alias        fastq_bytes  \
# 0  Cancer Cell Line Encyclopedia (CCLE)    HCC-56.bam   7773624;10209268
# 1  Cancer Cell Line Encyclopedia (CCLE)    HCC-78.bam    7530079;9978815
# 2  Cancer Cell Line Encyclopedia (CCLE)    HOP-62.bam   8058229;12501315
# 3  Cancer Cell Line Encyclopedia (CCLE)  NCI-H810.bam  13081808;17856519
# 4  Cancer Cell Line Encyclopedia (CCLE)  NCI-H322.bam  10400525;13057832
#
#                                            fastq_md5  \
# 0  ec71a964d91c08dd4161a5c51e8077ec;f9a75f6d1eb4b...
# 1  d4fd3f3baaefd30dd1b2ec8157737401;5110277bed499...
# 2  0912b268ba684b093da75cec18eea6d0;1112820fb4070...
# 3  89cd15c12b0e3f6d4aa8fa4d930c3768;ec17e81d32c65...
# 4  40188cfc8cb992e831837517b08b7216;1d9cda042e114...
#
#                                            fastq_ftp sra_bytes  \
# 0  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/003/SRR861...  18104962
# 1  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/004/SRR861...  17593943
# 2  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/005/SRR861...  21029304
# 3  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/002/SRR861...  30894571
# 4  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/007/SRR861...  23711511
#
#                             sra_md5  \
# 0  be2409df4f8c038b478bdef7d40683bc
# 1  caa4df8f8b40e416f0fa6b7f2c9328ae
# 2  7d4124ffdd0d7dc14f3ce2a22ff4c1d2
# 3  984e7fe6fbcbdbf30c5e3ae1dd57cd59
# 4  648268ec2fe15e87a64f0c0478bf825c
#
#                                             sra_ftp           sample_alias  \
# 0  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/003/SRR8615033  HCC56_LARGE_INTESTINE
# 1  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/004/SRR8615034             HCC78_LUNG
# 2  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/005/SRR8615035             HOP62_LUNG
# 3  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/002/SRR8615042           NCIH810_LUNG
# 4  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/007/SRR8615047           NCIH322_LUNG
#
#             sample_title
# 0  HCC56_LARGE_INTESTINE
# 1             HCC78_LUNG
# 2             HOP62_LUNG
# 3           NCIH810_LUNG
# 4           NCIH322_LUNG
#
# [5 rows x 24 columns]

# %%
# # print out information about dataframes and their columns

ena_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4550 entries, 0 to 4549
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   run_accession               4550 non-null   object
#  1   sample_accession            4550 non-null   object
#  2   secondary_sample_accession  4550 non-null   object
#  3   experiment_accession        4550 non-null   object
#  4   study_accession             4550 non-null   object
#  5   tax_id                      4550 non-null   int64
#  6   scientific_name             4550 non-null   object
#  7   instrument_platform         4550 non-null   object
#  8   library_layout              4550 non-null   object
#  9   library_source              4550 non-null   object
#  10  read_count                  4550 non-null   int64
#  11  base_count                  4550 non-null   int64
#  12  first_public                4550 non-null   object
#  13  last_updated                4550 non-null   object
#  14  study_title                 4550 non-null   object
#  15  run_alias                   4550 non-null   object
#  16  fastq_bytes                 4550 non-null   object
#  17  fastq_md5                   4550 non-null   object
#  18  fastq_ftp                   4550 non-null   object
#  19  sra_bytes                   4550 non-null   int64
#  20  sra_md5                     4550 non-null   object
#  21  sra_ftp                     4550 non-null   object
#  22  sample_alias                4550 non-null   object
#  23  sample_title                4550 non-null   object
# dtypes: int64(4), object(20)
# memory usage: 853.2+ KB

# %% [markdown]
# # Data from SRA RUN SELECTOR
# https://www.ncbi.nlm.nih.gov/Traces/study/?query_key=2&WebEnv=MCID_64deb5fe5542df760f04c853&o=acc_s%3Aa > Next to 4550 Runs, click "Metadata"
#
# Obtained: August 2023

# %%
# read ENA_browser_PRJNA523380.tsv file and store in ena_df
sra_df = pd.read_csv('./NCBI_SRA_runTable.csv', sep=',')
sra_df.head()
# Out:
#           Run   Age     Assay Type      AssemblyName  AvgSpotLen       Bases  \
# 0  SRR8633202  66.0  Bisulfite-Seq  GCA_000001405.13          29  1556265367
# 1  SRR8633203  74.0  Bisulfite-Seq  GCA_000001405.13          29  1727947890
# 2  SRR8633204  21.0  Bisulfite-Seq  GCA_000001405.13          29  3430374736
# 3  SRR8633205   NaN  Bisulfite-Seq  GCA_000001405.13          29  1359691158
# 4  SRR8633206   NaN  Bisulfite-Seq  GCA_000001405.13          29  2005765425
#
#   BIOMATERIAL_PROVIDER   BioProject     BioSample BioSampleModel  ...  \
# 0          DSMZ:HUP-T3  PRJNA523380  SAMN10987811          Human  ...
# 1         ATCC:Hs 578T  PRJNA523380  SAMN10987893          Human  ...
# 2        ATCC:Hs 604.T  PRJNA523380  SAMN10987929          Human  ...
# 3          RIKEN:HuH-6  PRJNA523380  SAMN10987713          Human  ...
# 4                HSSRB  PRJNA523380  SAMN10987843          Human  ...
#
#        Organism  Platform           ReleaseDate          Sample Name  \
# 0  Homo sapiens  ILLUMINA  2019-03-27T00:00:00Z       HUPT3_PANCREAS
# 1  Homo sapiens  ILLUMINA  2019-03-27T00:00:00Z        HS578T_BREAST
# 2  Homo sapiens  ILLUMINA  2019-03-27T00:00:00Z    HS604T_FIBROBLAST
# 3  Homo sapiens  ILLUMINA  2019-03-27T00:00:00Z           HUH6_LIVER
# 4  Homo sapiens  ILLUMINA  2019-03-27T00:00:00Z  HUH28_BILIARY_TRACT
#
#     Sample_type     sex  SRA Study                              Tissue  \
# 0  cell culture    male  SRP186687                            pancreas
# 1  cell culture  female  SRP186687                              breast
# 2  cell culture    male  SRP186687  haematopoietic_and_lymphoid_tissue
# 3  cell culture    male  SRP186687                               liver
# 4  cell culture     NaN  SRP186687                       biliary_tract
#
#             create_date version
# 0  2019-02-27T12:24:00Z     1.0
# 1  2019-02-27T12:25:00Z     1.0
# 2  2019-02-27T12:31:00Z     1.0
# 3  2019-02-27T12:23:00Z     1.0
# 4  2019-02-27T12:26:00Z     1.0
#
# [5 rows x 37 columns]

# %%
# print out information about dataframes and their columns
sra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4550 entries, 0 to 4549
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Run                   4550 non-null   object
#  1   Age                   3573 non-null   float64
#  2   Assay Type            4550 non-null   object
#  3   AssemblyName          4550 non-null   object
#  4   AvgSpotLen            4550 non-null   int64
#  5   Bases                 4550 non-null   int64
#  6   BIOMATERIAL_PROVIDER  4183 non-null   object
#  7   BioProject            4550 non-null   object
#  8   BioSample             4550 non-null   object
#  9   BioSampleModel        4550 non-null   object
#  10  Bytes                 4550 non-null   int64
#  11  Cell_line             4545 non-null   object
#  12  Center Name           4550 non-null   object
#  13  Consent               4550 non-null   object
#  14  DATASTORE filetype    4550 non-null   object
#  15  DATASTORE provider    4550 non-null   object
#  16  DATASTORE region      4550 non-null   object
#  17  disease               4510 non-null   object
#  18  disease_stage         4476 non-null   object
#  19  ETHNICITY             4494 non-null   object
#  20  Experiment            4550 non-null   object
#  21  Instrument            4550 non-null   object
#  22  Isolate               4550 non-null   object
#  23  Library Name          4550 non-null   object
#  24  LibraryLayout         4550 non-null   object
#  25  LibrarySelection      4550 non-null   object
#  26  LibrarySource         4550 non-null   object
#  27  Organism              4550 non-null   object
#  28  Platform              4550 non-null   object
#  29  ReleaseDate           4550 non-null   object
#  30  Sample Name           4550 non-null   object
#  31  Sample_type           4550 non-null   object
#  32  sex                   4023 non-null   object
#  33  SRA Study             4550 non-null   object
#  34  Tissue                4545 non-null   object
#  35  create_date           4543 non-null   object
#  36  version               4543 non-null   float64
# dtypes: float64(2), int64(3), object(32)
# memory usage: 1.3+ MB

# %% [markdown]
# # Getting RNA

# %%
terra_df[['stripped_cell_line_name']]
# Out:
#      stripped_cell_line_name
# 0                  NIHOVCAR3
# 1                       HL60
# 2                      CACO2
# 3                        HEL
# 4                    HEL9217
# ...                      ...
# 1055                   8305C
# 1056                   8505C
# 1057                 PLCPRF5
# 1058                      TT
# 1059                   SKNO1
#
# [1060 rows x 1 columns]

# %%
# Each row in ena_df['sample_alias'] is a concatenation of {CELLLINE}_{TISSUE}
# We want to split this into two columns: 'CELLLINE' and 'TISSUE'
# We can do this by splitting the string on the first underscore character

# Split the sample_alias column on the first underscore character
ena_df[['CELLLINE', 'TISSUE']] = ena_df['sample_alias'].str.split('_', 1, expand=True)
ena_df.head()
# Out:
# /tmp/ipykernel_845974/1694021606.py:6: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   ena_df[['CELLLINE', 'TISSUE']] = ena_df['sample_alias'].str.split('_', 1, expand=True)
#   run_accession sample_accession secondary_sample_accession  \
# 0    SRR8615033     SAMN10988141                 SRS4395287
# 1    SRR8615034     SAMN10988287                 SRS4395286
# 2    SRR8615035     SAMN10989587                 SRS4395285
# 3    SRR8615042     SAMN10987804                 SRS4395278
# 4    SRR8615047     SAMN10987678                 SRS4395273
#
#   experiment_accession study_accession  tax_id scientific_name  \
# 0           SRX5414207     PRJNA523380    9606    Homo sapiens
# 1           SRX5414206     PRJNA523380    9606    Homo sapiens
# 2           SRX5414205     PRJNA523380    9606    Homo sapiens
# 3           SRX5414198     PRJNA523380    9606    Homo sapiens
# 4           SRX5414193     PRJNA523380    9606    Homo sapiens
#
#   instrument_platform library_layout library_source  ...        fastq_bytes  \
# 0            ILLUMINA         PAIRED        GENOMIC  ...   7773624;10209268
# 1            ILLUMINA         PAIRED        GENOMIC  ...    7530079;9978815
# 2            ILLUMINA         PAIRED        GENOMIC  ...   8058229;12501315
# 3            ILLUMINA         PAIRED        GENOMIC  ...  13081808;17856519
# 4            ILLUMINA         PAIRED        GENOMIC  ...  10400525;13057832
#
#                                            fastq_md5  \
# 0  ec71a964d91c08dd4161a5c51e8077ec;f9a75f6d1eb4b...
# 1  d4fd3f3baaefd30dd1b2ec8157737401;5110277bed499...
# 2  0912b268ba684b093da75cec18eea6d0;1112820fb4070...
# 3  89cd15c12b0e3f6d4aa8fa4d930c3768;ec17e81d32c65...
# 4  40188cfc8cb992e831837517b08b7216;1d9cda042e114...
#
#                                            fastq_ftp sra_bytes  \
# 0  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/003/SRR861...  18104962
# 1  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/004/SRR861...  17593943
# 2  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/005/SRR861...  21029304
# 3  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/002/SRR861...  30894571
# 4  ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/007/SRR861...  23711511
#
#                             sra_md5  \
# 0  be2409df4f8c038b478bdef7d40683bc
# 1  caa4df8f8b40e416f0fa6b7f2c9328ae
# 2  7d4124ffdd0d7dc14f3ce2a22ff4c1d2
# 3  984e7fe6fbcbdbf30c5e3ae1dd57cd59
# 4  648268ec2fe15e87a64f0c0478bf825c
#
#                                             sra_ftp           sample_alias  \
# 0  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/003/SRR8615033  HCC56_LARGE_INTESTINE
# 1  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/004/SRR8615034             HCC78_LUNG
# 2  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/005/SRR8615035             HOP62_LUNG
# 3  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/002/SRR8615042           NCIH810_LUNG
# 4  ftp.sra.ebi.ac.uk/vol1/srr/SRR861/007/SRR8615047           NCIH322_LUNG
#
#             sample_title CELLLINE           TISSUE
# 0  HCC56_LARGE_INTESTINE    HCC56  LARGE_INTESTINE
# 1             HCC78_LUNG    HCC78             LUNG
# 2             HOP62_LUNG    HOP62             LUNG
# 3           NCIH810_LUNG  NCIH810             LUNG
# 4           NCIH322_LUNG  NCIH322             LUNG
#
# [5 rows x 26 columns]

# %%
# sra_df already has a cell_line column but its format might not be acceptable so split the Sample Name column
sra_df[['CELLLINE', 'TISSE']] = sra_df['Sample Name'].str.split('_', 1, expand=True)
sra_df[['Cell_line', 'CELLLINE', 'TISSE']]
# Out:
# /tmp/ipykernel_845974/1815170338.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   sra_df[['CELLLINE', 'TISSE']] = sra_df['Sample Name'].str.split('_', 1, expand=True)
#      Cell_line CELLLINE          TISSE
# 0       HUP-T3    HUPT3       PANCREAS
# 1      Hs 578T   HS578T         BREAST
# 2     Hs 604.T   HS604T     FIBROBLAST
# 3        HuH-6     HUH6          LIVER
# 4        HuH28    HUH28  BILIARY_TRACT
# ...        ...      ...            ...
# 4545     DAN-G     DANG       PANCREAS
# 4546   DMS 114   DMS114           LUNG
# 4547   DMS 273   DMS273           LUNG
# 4548     QGP-1     QGP1       PANCREAS
# 4549    HCC827   HCC827           LUNG
#
# [4550 rows x 3 columns]

# %%
sra_df.head()
# Out:
#           Run   Age     Assay Type      AssemblyName  AvgSpotLen       Bases  \
# 0  SRR8633202  66.0  Bisulfite-Seq  GCA_000001405.13          29  1556265367
# 1  SRR8633203  74.0  Bisulfite-Seq  GCA_000001405.13          29  1727947890
# 2  SRR8633204  21.0  Bisulfite-Seq  GCA_000001405.13          29  3430374736
# 3  SRR8633205   NaN  Bisulfite-Seq  GCA_000001405.13          29  1359691158
# 4  SRR8633206   NaN  Bisulfite-Seq  GCA_000001405.13          29  2005765425
#
#   BIOMATERIAL_PROVIDER   BioProject     BioSample BioSampleModel  ...  \
# 0          DSMZ:HUP-T3  PRJNA523380  SAMN10987811          Human  ...
# 1         ATCC:Hs 578T  PRJNA523380  SAMN10987893          Human  ...
# 2        ATCC:Hs 604.T  PRJNA523380  SAMN10987929          Human  ...
# 3          RIKEN:HuH-6  PRJNA523380  SAMN10987713          Human  ...
# 4                HSSRB  PRJNA523380  SAMN10987843          Human  ...
#
#             ReleaseDate          Sample Name   Sample_type     sex  SRA Study  \
# 0  2019-03-27T00:00:00Z       HUPT3_PANCREAS  cell culture    male  SRP186687
# 1  2019-03-27T00:00:00Z        HS578T_BREAST  cell culture  female  SRP186687
# 2  2019-03-27T00:00:00Z    HS604T_FIBROBLAST  cell culture    male  SRP186687
# 3  2019-03-27T00:00:00Z           HUH6_LIVER  cell culture    male  SRP186687
# 4  2019-03-27T00:00:00Z  HUH28_BILIARY_TRACT  cell culture     NaN  SRP186687
#
#                                Tissue           create_date version CELLLINE  \
# 0                            pancreas  2019-02-27T12:24:00Z     1.0    HUPT3
# 1                              breast  2019-02-27T12:25:00Z     1.0   HS578T
# 2  haematopoietic_and_lymphoid_tissue  2019-02-27T12:31:00Z     1.0   HS604T
# 3                               liver  2019-02-27T12:23:00Z     1.0     HUH6
# 4                       biliary_tract  2019-02-27T12:26:00Z     1.0    HUH28
#
#            TISSE
# 0       PANCREAS
# 1         BREAST
# 2     FIBROBLAST
# 3          LIVER
# 4  BILIARY_TRACT
#
# [5 rows x 39 columns]

# %%
# get the row with the lowest sra_bytes in ena_df
ena_df.loc[ena_df['sra_bytes'].idxmin()]
# Out:
# run_accession                                                        SRR8615081
# sample_accession                                                   SAMN10987705
# secondary_sample_accession                                           SRS4395239
# experiment_accession                                                 SRX5414159
# study_accession                                                     PRJNA523380
# tax_id                                                                     9606
# scientific_name                                                    Homo sapiens
# instrument_platform                                                    ILLUMINA
# library_layout                                                           PAIRED
# library_source                                                          GENOMIC
# read_count                                                                10818
# base_count                                                              3245400
# first_public                                                         2019-03-28
# last_updated                                                         2019-03-28
# study_title                                Cancer Cell Line Encyclopedia (CCLE)
# run_alias                                                        ACC-MESO-1.bam
# fastq_bytes                                                       525302;830170
# fastq_md5                     21ea8c10bc7ca9362afe39adbae80d07;002ddc347a454...
# fastq_ftp                     ftp.sra.ebi.ac.uk/vol1/fastq/SRR861/001/SRR861...
# sra_bytes                                                               1571192
# sra_md5                                        dc571eaab32ec6119c2fb7c7cc1525f2
# sra_ftp                        ftp.sra.ebi.ac.uk/vol1/srr/SRR861/001/SRR8615081
# sample_alias                                                    ACCMESO1_PLEURA
# sample_title                                                    ACCMESO1_PLEURA
# CELLLINE                                                               ACCMESO1
# TISSUE                                                                   PLEURA
# Name: 400, dtype: object

# %%
# get row where run_accession is SRR8615788
ena_df.loc[ena_df['run_accession'] == 'SRR8615788']['sra_bytes']
# Out:
# 314    8680933841
# Name: sra_bytes, dtype: int64
